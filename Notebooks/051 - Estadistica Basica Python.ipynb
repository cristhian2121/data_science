# %% [markdown]
# # Estadística Básica

# %%
# Importación de librerías
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from scipy import stats as ss

# %% [markdown]
# - Objetivos y uso de la estadística descriptiva
# - Tipos de variables
# - Histogramas y medidas de tendencia central
# - Medidas de dispérsión
# - Medidas de posición. Cuartiles, deciles y percentiles

# %% [markdown]
# ## Medidas estadísticas
#
# Tenemos 3 medidas basicas para describir a los datos:
#
# - Medidas de tendencia central (un solo número nos da mucha información)
# - Medidas de disperción (necesita una medida de tendencia central)
# - Medidas de posición (dividirlo por partes)
# ---

# %% [markdown]
# ## Medidas de tendencia central
#
# - **Moda:** Es el valor que mas se repite en un dato de tipo nominal (la categoria que mas se repite)
# - **Media (Promedio):** suma de los elementos / total de los elementos
# - **Mediana:** Ordenar los elementos, partir el conjunto de datos en 2 y seleccionar el punto medio
#
#
# Siempre validar promedios con las medianas y/o medidas de posición,
# Tambien nos podemos ayudar de segmentaciones, las cuales agrupan cosas similares entre si, lo que significa que los promedios de esos segmentos se van a parecer mucho mas a los valores individuales de cada uno de los objetos que lo componen.
#
# ---

# %% [markdown]
# ## Medidas de dispersión
#
# - **Rango:** Es la resta entre el valor maximo y minimo
# - **Varianza:** Distancia que hay entre el promedio y cada una de las observaciones, elevado al cuadrado
# - **Desviación estandar:** raíz cuadrada de la varianza
# - **Coeficiente de variación:** Es la división entre la desviación estandar y la media (Datos mayores a 1 datos muy dispersos, si estan por debajo de 0.5 estan muy concentrado entorno a la media)
#
#
# Nos indican si una variable se mueve mucho o cambia muchos respecto a sus datos.
#
# En este sentido, deben acompañar a las medidas de tendencia central. Juntas, ofrecen información de un sólo vistazo que luego podremos utilizar para comparar y, si fuera preciso, tomar decisiones.
#
# ---

# %%
arreglo_medidas_tc = np.array([1,2,2,3,3,4,4,4,4,5,5])

# %%
arreglo_medidas_tc.mean()
# Out:
# 3.3636363636363638

# %%
np.median(arreglo_medidas_tc)
# Out:
# 4.0

# %%
ss.mode(arreglo_medidas_tc)
# Out:
# ModeResult(mode=array([4]), count=array([4]))

# %%
arreglo_medidas_tc.max() - arreglo_medidas_tc.min()
# Out:
# 4

# %%
arreglo_medidas_tc.var()
# Out:
# 1.5041322314049588

# %%
arreglo_medidas_tc.std()
# Out:
# 1.2264306875665492

# %%
arreglo_medidas_tc.std() / arreglo_medidas_tc.mean()
# Out:
# 0.3646145287360011

# %% [markdown]
# # Medidas de posición
#
# Hacen referencia a como su nombre lo indica a una posición de ubicación de los datos respecto a todos los datos de un conjunto de datos ordenados de menor a mayor.
#
# ![image-2.png](attachment:image-2.png)
#
# - **Cuartiles:** (K*n) / 4
# - **Deciles:**  (K*n) / 10
# - **Percentiles:**  (K*n) / 100
#
# **K:** posición del cuartil, decil o percentil
#
# **n:** Cantidad de datos
#
# ---
#
# **Ejemplos:**
#
# **Cuartil:**
#
# (2*9) / 4 = 4.5 (el resultado indica la posición)
#
#
# 1,2,4,5,6,6,7,9,9
#
# ---
#
# **Decil:**
#
# (8*15) / 10 = 12
#
# 1,2,4,5,6,6,7,9,9,10,11,12,15,16,20
#
# ---
#
# **Percentil:**
#
# (70*10) / 100 = 7
#
#
#
#
# 1,2,4,5,6,6,7,9,9
#
# ---

# %%
arreglo = np.array([1,2,4,5,6,6,7,9,9])
arreglo
# Out:
# array([1, 2, 4, 5, 6, 6, 7, 9, 9])

# %% [markdown]
# **Mediana**

# %%
np.median(arreglo)
# Out:
# 6.0

# %% [markdown]
# **Cuartiles**

# %%
np.quantile(arreglo, 0.5)
# Out:
# 6.0

# %%
np.quantile(arreglo, 0.25)
# Out:
# 4.0

# %%
np.quantile(arreglo, 0.75)
# Out:
# 7.0

# %% [markdown]
# **Percentil**

# %%
np.percentile(arreglo, 8)
# Out:
# 1.6400000000000001

# %%
np.percentile(arreglo, 99)
# Out:
# 9.0

# %%
np.percentile(arreglo, 50)
# Out:
# 6.0

# %%
np.percentile(arreglo, 25)
# Out:
# 4.0

# %% [markdown]
# # Histograma
#
# El histograma es una representación gráfica que muestra la distribución de probabilidad de una variable a lo largo de su recorrido, mediante la frecuencia de aparición de datos a lo largo del recorrido de la variable.
#
# Es importante considerar que la frecuencia de aparición dependerá del intervalo que se estime, mediante el valor mínimo y máximo de la variable.
#
#
# Veamos un ejemplo práctico de un histograma.

# %%
mu = 100 # media (centro)
sigma = 100 # desviación estándar
cantidad = 1000 # tamaño

# muestras aleatorias de una distribución normal (gaussiana)
x = np.random.normal(mu, sigma, cantidad).reshape(cantidad,)
y = np.zeros(cantidad)

plt.plot(x, y, 'o', color='black')
plt.show()

# %%
bins = 10
plt.hist(x, bins)
plt.show()

# %%
mu = 1 # media (centro)
sigma = 100 # desviación estándar
cantidad = 1000 # tamaño

# muestras aleatorias de una distribución normal (gaussiana)
x = np.random.normal(mu, sigma, cantidad).reshape(cantidad,)
y = np.zeros(cantidad)

plt.plot(x, y, 'o', color='black')
plt.show()

plt.hist(x)
plt.show()

# %%
np.mean(x)
# Out:
# -0.15648689986547015

# %%
np.median(x)
# Out:
# 1.0094927574504875

# %%
np.std(x)
# Out:
# 100.87487005081111

# %% [markdown]
# Entre mas alto un compartimiento, mas medidas estan dentro de ese compartimiento
#
# Los histogramas se pueden usar para visualizar facilmente una distribución y poder observar la probabilidad de futuros de datos.

# %% [markdown]
# # Caso de cotton plus

# %% [markdown]
# ### Realiza la lectura del dataset 'Data DS Cotton Plus'

# %%
df_cotton_plus = pd.read_excel('Data DS Cotton Plus.xlsx', sheet_name='BD')
df_cotton_plus
# Out:
#       Cedula      Nombre Completo     Segmento Compro 2019? Compro 2020?  \
# 0          1     Nombre Cliente 1  Aficionados           Si           No
# 1          2     Nombre Cliente 2  Esporádicos           Si           No
# 2          3     Nombre Cliente 3  Aficionados           Si           No
# 3          4     Nombre Cliente 4  Aficionados           Si           No
# 4          5     Nombre Cliente 5  Aficionados           Si           No
# ...      ...                  ...          ...          ...          ...
# 9971    9972  Nombre Cliente 9972  Aficionados           Si           No
# 9972    9973  Nombre Cliente 9973  Aficionados           Si           No
# 9973    9974  Nombre Cliente 9974  Aficionados           Si           No
# 9974    9975  Nombre Cliente 9975  Esporádicos           Si           No
# 9975    9976  Nombre Cliente 9976  Esporádicos           No           No
#
#       Monto Comprado 2019?  Nro Transacciones 2019  Monto Comprado 2020  \
# ...

# %% [markdown]
# ### Visualiza la información de las variables en el dataset: sus tipos y cantidad de valores nulos

# %%
df_cotton_plus.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9976 entries, 0 to 9975
# Data columns (total 40 columns):
#  #   Column                                                            Non-Null Count  Dtype
# ---  ------                                                            --------------  -----
#  0   Cedula                                                            9976 non-null   int64
#  1   Nombre Completo                                                   9976 non-null   object
#  2   Segmento                                                          9976 non-null   object
#  3   Compro 2019?                                                      9976 non-null   object
#  4   Compro 2020?                                                      9976 non-null   object
#  5   Monto Comprado 2019?                                              9976 non-null   int64
#  6   Nro Transacciones 2019                                            9976 non-null   int64
# ...

# %%
df_cotton_plus.columns
# Out:
# Index(['Cedula', 'Nombre Completo', 'Segmento', 'Compro 2019?', 'Compro 2020?',
#        'Monto Comprado 2019?', 'Nro Transacciones 2019', 'Monto Comprado 2020',
#        'Nro Transacciones 2020', 'Tipo de Contacto', 'Es Contactable',
#        'Ciudad de Residencia', 'Mail', 'Direccion', 'Genero', 'Estado Civil',
#        'Fecha Nacimiento', 'Mes Nacimiento', 'Dia Nacimiento', 'Edad',
#        'Monto Total de ultima compra', 'Cantidad Articulos',
#        'Recencia (Tiempo transcurrido en semanas desde su ultima compra)',
#        'Frecuencia (Cantidad items comprados)', 'Direccion Valido?',
#        'Mail Valido?', 'Cel Valido?', 'Tel Ofc Valid?', 'Tel Casa Valido?',
#        'Telefono Movil', 'TelefonoOficina', 'Telefono Casa',
#        'Monto - MARCA COTTON- B/quilla.', 'Monto - Brand Store Cucuta',
#        'Monto - MARCA COTTON- Bucaramanga', 'Monto - MARCA COTTON- Manizales',
#        'Monto - MARCA COTTON- Pereira', 'Monto - MARCA COTTON- Cartagena',
# ...

# %% [markdown]
# ### Elimina las variables con el total de sus registros nulos

# %%
#df_cotton_plus.drop(['Mail', 'Direccion', 'Telefono Movil', 'TelefonoOficina', 'Telefono Casa'], axis=1, inplace=True)
df_cotton_plus
# Out:
#       Cedula      Nombre Completo     Segmento Compro 2019? Compro 2020?  \
# 0          1     Nombre Cliente 1  Aficionados           Si           No
# 1          2     Nombre Cliente 2  Esporádicos           Si           No
# 2          3     Nombre Cliente 3  Aficionados           Si           No
# 3          4     Nombre Cliente 4  Aficionados           Si           No
# 4          5     Nombre Cliente 5  Aficionados           Si           No
# ...      ...                  ...          ...          ...          ...
# 9971    9972  Nombre Cliente 9972  Aficionados           Si           No
# 9972    9973  Nombre Cliente 9973  Aficionados           Si           No
# 9973    9974  Nombre Cliente 9974  Aficionados           Si           No
# 9974    9975  Nombre Cliente 9975  Esporádicos           Si           No
# 9975    9976  Nombre Cliente 9976  Esporádicos           No           No
#
#       Monto Comprado 2019?  Nro Transacciones 2019  Monto Comprado 2020  \
# ...

# %%
df_cotton_plus_no_null = df_cotton_plus.drop(['Mail', 'Direccion', 'Telefono Movil', 'TelefonoOficina', 'Telefono Casa'], axis=1).copy()
df_cotton_plus_no_null
# Out:
#       Cedula      Nombre Completo     Segmento Compro 2019? Compro 2020?  \
# 0          1     Nombre Cliente 1  Aficionados           Si           No
# 1          2     Nombre Cliente 2  Esporádicos           Si           No
# 2          3     Nombre Cliente 3  Aficionados           Si           No
# 3          4     Nombre Cliente 4  Aficionados           Si           No
# 4          5     Nombre Cliente 5  Aficionados           Si           No
# ...      ...                  ...          ...          ...          ...
# 9971    9972  Nombre Cliente 9972  Aficionados           Si           No
# 9972    9973  Nombre Cliente 9973  Aficionados           Si           No
# 9973    9974  Nombre Cliente 9974  Aficionados           Si           No
# 9974    9975  Nombre Cliente 9975  Esporádicos           Si           No
# 9975    9976  Nombre Cliente 9976  Esporádicos           No           No
#
#       Monto Comprado 2019?  Nro Transacciones 2019  Monto Comprado 2020  \
# ...

# %%
df_cotton_plus_no_null['Monto - MARCA COTTON- B/quilla.'].value_counts()
# Out:
# 0          9477
# 129900       16
# 169900       15
# 179900       10
# 139900        9
#            ...
# 387600        1
# 776790        1
# 469600        1
# 305800        1
# 1011890       1
# Name: Monto - MARCA COTTON- B/quilla., Length: 385, dtype: int64

# %%
valores_cero = df_cotton_plus_no_null[df_cotton_plus_no_null['Monto - MARCA COTTON- B/quilla.'] == 0]
valores_cero
# Out:
#       Cedula      Nombre Completo     Segmento Compro 2019? Compro 2020?  \
# 0          1     Nombre Cliente 1  Aficionados           Si           No
# 3          4     Nombre Cliente 4  Aficionados           Si           No
# 4          5     Nombre Cliente 5  Aficionados           Si           No
# 6          7     Nombre Cliente 7  Aficionados           No           No
# 7          8     Nombre Cliente 8  Aficionados           Si           No
# ...      ...                  ...          ...          ...          ...
# 9971    9972  Nombre Cliente 9972  Aficionados           Si           No
# 9972    9973  Nombre Cliente 9973  Aficionados           Si           No
# 9973    9974  Nombre Cliente 9974  Aficionados           Si           No
# 9974    9975  Nombre Cliente 9975  Esporádicos           Si           No
# 9975    9976  Nombre Cliente 9976  Esporádicos           No           No
#
#       Monto Comprado 2019?  Nro Transacciones 2019  Monto Comprado 2020  \
# ...

# %%
df_cotton_plus_no_null['Monto - MARCA COTTON- B/quilla.'] = df_cotton_plus_no_null['Monto - MARCA COTTON- B/quilla.'].replace({0: 1})
df_cotton_plus_no_null['Monto - MARCA COTTON- B/quilla.'].unique()
# Out:
# array([      1,  179900,  451200,  387600,  719500,  188830, 5729890,
#         802290,  369700,  328090, 1810100,  617780,  306800,  208700,
#          54900,  274800,  257850,  319700,  809220, 1014200,  224220,
#         119900,  244300, 2037200, 6120160,  294700, 3131740,  559600,
#         129900,  249800,  203800,  509600,  634520,  359800,   39900,
#        2685040,  339800,  397580,   76230,  139900,  429700,  612500,
#         199800,  165820,  256380,  267700,  338670,  883840,  134900,
#         595400,  526460,  185380,  680400,  451100,  670300,  269800,
#         831200,  139800,   69900,  234800, 1515240,  313600,  199700,
#          59900,  337700,  124900,  486540,  379700,  157840,  432120,
#         369600,  162900,  248830,  456600,  169900,  432600,  333700,
#         385500,  741400, 1387320,   84950,  151920,  879260,  136640,
#         341700, 2279310,  483070,  236950,  494360,  344940,  378400,
# ...

# %% [markdown]
# ### Realizar una descripción de las variables numéricas

# %%
df_cotton_plus_no_null.describe().T
# Out:
#                                                      count          mean  \
# Cedula                                              9976.0  4.988500e+03
# Monto Comprado 2019?                                9976.0  2.438670e+05
# Nro Transacciones 2019                              9976.0  2.462711e+00
# Monto Comprado 2020                                 9976.0  2.506701e+04
# Nro Transacciones 2020                              9976.0  2.635325e-01
# Tipo de Contacto                                    9976.0  9.268515e+03
# Fecha Nacimiento                                    9976.0  1.955487e+07
# Dia Nacimiento                                      9976.0  1.510876e+01
# Edad                                                9976.0  4.036187e+01
# Monto Total de ultima compra                        9976.0  5.902064e+05
# Cantidad Articulos                                  9976.0  1.196933e+01
# Recencia (Tiempo transcurrido en semanas desde ...  9976.0  1.042382e+01
# ...

# %% [markdown]
# ### Calcular los cuartiles de la variable 'Edad'

# %%
df_cotton_plus_no_null["Edad"].describe()
# Out:
# count    9976.000000
# mean       40.361868
# std        26.029822
# min        10.000000
# 25%        25.000000
# 50%        31.000000
# 75%        44.000000
# max       111.000000
# Name: Edad, dtype: float64

# %%
df_cotton_plus_no_null["Edad"].quantile([0, 0.25, 0.5, 0.75, 1])
# Out:
# 0.00     10.0
# 0.25     25.0
# 0.50     31.0
# 0.75     44.0
# 1.00    111.0
# Name: Edad, dtype: float64

# %%
df_cotton_plus_no_null["Edad"].describe([.01, .1, .2, .3, .4, .5, .6, .7, .8, .9, .975])
# Out:
# count    9976.000000
# mean       40.361868
# std        26.029822
# min        10.000000
# 1%         16.000000
# 10%        21.000000
# 20%        24.000000
# 30%        26.000000
# 40%        29.000000
# 50%        31.000000
# 60%        35.000000
# 70%        40.000000
# 80%        47.000000
# 90%       110.000000
# 97.5%     111.000000
# max       111.000000
# Name: Edad, dtype: float64

# %%
df_cotton_plus_no_null["Edad"].value_counts()
# Out:
# 111    534
# 110    512
# 26     436
# 25     435
# 29     425
#       ...
# 76       1
# 68       1
# 83       1
# 79       1
# 81       1
# Name: Edad, Length: 73, dtype: int64

# %%
df_cotton_plus_no_null["Edad"].median()
# Out:
# 31.0

# %%
boxplot = df_cotton_plus_no_null.boxplot(column = ['Edad'])

# %% [markdown]
# ### Graficar el histograma de la variable 'Edad'

# %%
plt.hist(df_cotton_plus_no_null['Edad'])
# Out:
# (array([9.590e+02, 3.782e+03, 2.269e+03, 1.334e+03, 4.810e+02, 8.800e+01,
#         1.400e+01, 2.000e+00, 1.000e+00, 1.046e+03]),
#  array([ 10. ,  20.1,  30.2,  40.3,  50.4,  60.5,  70.6,  80.7,  90.8,
#         100.9, 111. ]),
#  <a list of 10 Patch objects>)

# %% [markdown]
# ### Implementando agg para agregar operaciones

# %% [markdown]
# El método de las series pandas **pandas.Series.agg** aplica una o más funciones de agregación a los valores de la serie. La función a aplicar deberá pasarse como primer argumento y tendrá que ser el nombre de una función Python, una cadena de texto representando una función válida o un diccionario. En el caso de querer aplicar más de una función de agregación, éstas deberán pasarse como una lista.

# %%
print(pd.Series.agg.__doc__)
# Out:
# Aggregate using one or more operations over the specified axis.
#
# .. versionadded:: 0.20.0
#
# Parameters
# ----------
# func : function, str, list or dict
#     Function to use for aggregating the data. If a function, must either
#     work when passed a Series or when passed to Series.apply.
#
#     Accepted combinations are:
#
#     - function
#     - string function name
#     - list of functions and/or function names, e.g. ``[np.sum, 'mean']``
#     - dict of axis labels -> functions, function names or list of such.
# axis : {0 or 'index'}
#         Parameter needed for compatibility with DataFrame.
# *args
#     Positional arguments to pass to `func`.
# **kwargs
#     Keyword arguments to pass to `func`.
#
# Returns
# -------
# scalar, Series or DataFrame
#
#     The return can be:
#
#     * scalar : when Series.agg is called with single function
#     * Series : when DataFrame.agg is called with a single function
# ...

# %%
df_cotton_plus_no_null.agg({'Monto Comprado 2019?':['sum','mean','median'],
                    'Monto Total de ultima compra':['mean']                                    
                                     }).T
# Out:
#                                        mean    median           sum
# Monto Comprado 2019?          243866.951784  113485.0  2.432817e+09
# Monto Total de ultima compra  590206.416500       NaN           NaN

# %%
print(pd.Series.groupby.__doc__)
# Out:
# Group Series using a mapper or by a Series of columns.
#
# A groupby operation involves some combination of splitting the
# object, applying a function, and combining the results. This can be
# used to group large amounts of data and compute operations on these
# groups.
#
# Parameters
# ----------
# by : mapping, function, label, or list of labels
#     Used to determine the groups for the groupby.
#     If ``by`` is a function, it's called on each value of the object's
#     index. If a dict or Series is passed, the Series or dict VALUES
#     will be used to determine the groups (the Series' values are first
#     aligned; see ``.align()`` method). If an ndarray is passed, the
#     values are used as-is determine the groups. A label or list of
#     labels may be passed to group by the columns in ``self``. Notice
#     that a tuple is interpreted as a (single) key.
# axis : {0 or 'index', 1 or 'columns'}, default 0
#     Split along rows (0) or columns (1).
# ...

# %%
df_cotton_plus_no_null.groupby('Genero').agg({'Nro Transacciones 2020':['count','mean','median','std']                                          
                                     })
# Out:
#        Nro Transacciones 2020
#                         count      mean median       std
# Genero
# Hombre                   3996  0.236486      0  1.074161
# Mujer                    5980  0.281605      0  1.411478

# %%
df_cotton_plus_no_null.groupby(['Genero', 'Segmento']).agg({'Edad':'min'})
# Out:
#                     Edad
# Genero Segmento
# Hombre Adictos        20
#        Aficionados    10
#        Curiosos       18
#        Esporádicos    14
#        Inactivo       18
# Mujer  Adictos        15
#        Aficionados    11
#        Curiosos       17
#        Esporádicos    11
#        Inactivo       21

# %%
print(type(df_cotton_plus_no_null.groupby(['Genero', 'Segmento']).agg({'Edad':'min'})))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
# Procedimiento que sigue el mismo comportamiento que la celda anterior, cuando se va a calcular una función según una variable.
# df_cotton_plus_no_null.groupby(['Genero', 'Segmento']).Edad.min()
df_cotton_plus_no_null.groupby(['Genero', 'Segmento'])['Edad'].min()
# Out:
# Genero  Segmento
# Hombre  Adictos        20
#         Aficionados    10
#         Curiosos       18
#         Esporádicos    14
#         Inactivo       18
# Mujer   Adictos        15
#         Aficionados    11
#         Curiosos       17
#         Esporádicos    11
#         Inactivo       21
# Name: Edad, dtype: int64

# %%
type(df_cotton_plus_no_null.groupby(['Genero', 'Segmento']).Edad.min())
# Out:
# pandas.core.series.Series

# %%
# De un pandas Series a un pandas DataFrame con reset_index()
df_cotton_plus_no_null.groupby(['Genero', 'Segmento'])['Edad'].sum().reset_index()
# Out:
#    Genero     Segmento    Edad
# 0  Hombre      Adictos    2532
# 1  Hombre  Aficionados  106355
# 2  Hombre     Curiosos    2975
# 3  Hombre  Esporádicos   39975
# 4  Hombre     Inactivo    5718
# 5   Mujer      Adictos    4950
# 6   Mujer  Aficionados  162129
# 7   Mujer     Curiosos    6167
# 8   Mujer  Esporádicos   58303
# 9   Mujer     Inactivo   13546

# %%
type(df_cotton_plus_no_null.groupby(['Genero', 'Segmento'])['Edad'].sum().reset_index())
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# ## Taller práctico

# %% [markdown]
# ### Tablas de frecuencia

# %% [markdown]
# #### Clientes por Segmento

# %% [markdown]
# Obtener la **frecuencia** de clientes por Segmento

# %%
df_cotton_plus_no_null[""].hist()
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f468c39ee50>,
# ...
#       dtype=object)

# %% [markdown]
# Generar un **DataFrame** de la frecuencia calculada en la celda anterior

# %% [markdown]
# A partir del DataFrame anterior, incluir una **nueva columna** con el calculo del porcentaje de Participacion **(% Participacion)** de los clientes por Segmento

# %% [markdown]
# #### Clientes por transacciones en el 2019

# %% [markdown]
# Obtener la **frecuencia** de clientes por transacciones en el 2019

# %% [markdown]
# Generar un **DataFrame** de la frecuencia calculada en la celda anterior

# %% [markdown]
# A partir del DataFrame anterior, incluir una **nueva columna** con el calculo del porcentaje de Participacion **(% Participacion)** de los clientes por transacciones en el 2019

# %% [markdown]
# #### Segmentos por realización de compras en el 2019 (sobre el total del año)

# %% [markdown]
# Obtener la **frecuencia** de clientes por compras en el 2019 y Segmento

# %% [markdown]
# Generar un **DataFrame** de la frecuencia calculada en la celda anterior.
#
# **Requisito:** Hacer uso de unstack() para pivotear las etiquetas del índice (dejar parámetros por defecto).

# %% [markdown]
# Transponer el DataFrame de la celda anterior

# %% [markdown]
# Hacer uso del método fillna() para reemplazar o completar los valores NA/NaN por 0, en la columna que corresponda

# %% [markdown]
# Calcular el porcentaje correspondiente a las compras ("Si") y no compras ("No") del total en 2019 a partir del DataFrame generado en las celdas anteriores. Se requiere incluirle al DataFrame estas dos nuevas columnas "% No" y "% Si".
